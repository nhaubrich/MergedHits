# %%
### Test the format of the plots ###

import matplotlib.pyplot as plt
from random import random
# %matplotlib inline

datafilenames = ["SharedHits/NormalizedCharge/output_final_1.h5","SharedHits/AbsoluteCharge/output_final_1.h5",
                "Shared100NonShared/NormalizedCharge/output_final_1.h5","Shared100NonShared/AbsoluteCharge/output_final_1.h5",
                "AllHits/NormalizedCharge/output_final_1.h5","AllHits/AbsoluteCharge/output_final_1.h5"]

fig = plt.figure()

for counter,name in enumerate(datafilenames):
    
    # Text for the cuts
    if counter == 0 or counter == 1: 
        cuttitle = "nUniqueSimTracksInSharedHit >= 0"
        stringforcut = "(df['nUniqueSimTracksInSharedHit']>=0)"
    if counter == 2 or counter == 3: 
        cuttitle = "nUniqueSimTracksInSharedHit != (0|1)"
        stringforcut = '(df["nUniqueSimTracksInSharedHit"]!=0) & (df["nUniqueSimTracksInSharedHit"]!=1)'
    if counter == 4 or counter == 5: 
        cuttitle = "nUniqueSimTracksInSharedHit != (0|1)"
        stringforcut = '(df["nUniqueSimTracksInSharedHit"]!=0) & (df["nUniqueSimTracksInSharedHit"]!=1)'
    
    ax = fig.add_subplot(3,2,counter+1)
    ax.plot([(random(), random()), (random(), random())])
    ax.set_title("ROC Curve"+"\n"+name[:-18]+"\n"+cuttitle+"\n"+"Area = (...)")
    ax.set_xlabel('False positive rate')
    ax.set_ylabel('True positive rate')

fig.set_size_inches(10, 10)
fig.tight_layout()
plt.show()

# %%
### Test the format of the plots ###

import matplotlib.pyplot as plt
from random import random
# %matplotlib inline

datafilenames = ["SharedHits/NormalizedCharge/output_final_1.h5","SharedHits/AbsoluteCharge/output_final_1.h5",
                "Shared100NonShared/NormalizedCharge/output_final_1.h5","Shared100NonShared/AbsoluteCharge/output_final_1.h5",
                "AllHits/NormalizedCharge/output_final_1.h5","AllHits/AbsoluteCharge/output_final_1.h5"]

fig = plt.figure()

for counter,name in enumerate(datafilenames[3:5]):
    
    # Text for the cuts
    if counter == 0 or counter == 1: 
        cuttitle = "nUniqueSimTracksInSharedHit >= 0"
        stringforcut = "(df['nUniqueSimTracksInSharedHit']>=0)"
    if counter == 2 or counter == 3: 
        cuttitle = "nUniqueSimTracksInSharedHit != (0|1)"
        stringforcut = '(df["nUniqueSimTracksInSharedHit"]!=0) & (df["nUniqueSimTracksInSharedHit"]!=1)'
    if counter == 4 or counter == 5: 
        cuttitle = "nUniqueSimTracksInSharedHit != (0|1)"
        stringforcut = '(df["nUniqueSimTracksInSharedHit"]!=0) & (df["nUniqueSimTracksInSharedHit"]!=1)'
    
    ax = fig.add_subplot(1,2,counter+1)
    ax.plot([(random(), random()), (random(), random())])
    ax.set_title("ROC Curve"+"\n"+name[:-18]+"\n"+cuttitle+"\n"+"Area = (...)")
    ax.set_xlabel('False positive rate')
    ax.set_ylabel('True positive rate')

fig.set_size_inches(15, 6)
fig.tight_layout()
plt.show()

# %% [markdown]
# # $\Delta x$ Plots

# %%
### Test the format of the plots ###

import matplotlib.pyplot as plt
from random import random
# %matplotlib inline

datafilenames = ["SharedHits/NormalizedCharge/output_final_1.h5","SharedHits/AbsoluteCharge/output_final_1.h5",
                "Shared100NonShared/NormalizedCharge/output_final_1.h5","Shared100NonShared/AbsoluteCharge/output_final_1.h5",
                "AllHits/NormalizedCharge/output_final_1.h5","AllHits/AbsoluteCharge/output_final_1.h5"]

fig = plt.figure()

for counter,name in enumerate(datafilenames):
    
    # Text for the cuts
    if counter == 0 or counter == 1: 
        cuttitle = "nUniqueSimTracksInSharedHit >= 0"
        stringforcut = "(df['nUniqueSimTracksInSharedHit']>=0)"
    if counter == 2 or counter == 3: 
        cuttitle = "nUniqueSimTracksInSharedHit != (0|1)"
        stringforcut = '(df["nUniqueSimTracksInSharedHit"]!=0) & (df["nUniqueSimTracksInSharedHit"]!=1)'
    if counter == 4 or counter == 5: 
        cuttitle = "nUniqueSimTracksInSharedHit != (0|1)"
        stringforcut = '(df["nUniqueSimTracksInSharedHit"]!=0) & (df["nUniqueSimTracksInSharedHit"]!=1)'
    
    ax = fig.add_subplot(3,2,counter+1)
    ax.plot([(random(), random()), (random(), random())])
    ax.set_title("ROC Curve"+"\n"+name[:-18]+"\n"+cuttitle+"\n"+"Area = (...)")
    ax.set_xlabel('False positive rate')
    ax.set_ylabel('True positive rate')

fig.set_size_inches(10, 10)
fig.tight_layout()
plt.show()

# %%
# Plotting CNN Signal and Background Width
signal_plt_width = signal["Width"]
background_plt_width = background["Width"]
plt.hist(signal_plt_width,  alpha = 0.5, color = 'b', label = 'Merged Hit', range = (1,10), bins = 9)
plt.hist(background_plt_width, alpha = 0.5, color = 'r', label = 'Not Merged Hit', range = (1,10), bins = 9)
plt.legend(loc='best')
plt.title('Merged vs Not Merged $\Delta x$ in Testing Data')
plt.xlabel('$\Delta x$')
plt.ylabel('Reconstructed $\Lambda$s')

# Add subplot
ax = fig.add_subplot(3,2,counter+1)
ax.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc))
ax.set_title("ROC Curve"+"\n"+datafilename[:-18]+"\n"+cuttitle+"\n"+"Area = {:.3f}".format(auc))
ax.set_xlabel('False positive rate')
ax.set_ylabel('True positive rate')
